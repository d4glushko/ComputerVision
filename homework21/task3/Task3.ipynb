# %%
import cv2
import numpy as np
import imutils
from skimage.feature import peak_local_max
from skimage.morphology import watershed
from scipy import ndimage

from skimage import io
from matplotlib import pyplot as plt
from PIL import ImageEnhance, Image
from google.colab.patches import cv2_imshow

# %%
def url_to_image(url):
  print("downloading %s" % (url))
  return cv2.cvtColor(io.imread(url), cv2.COLOR_BGR2RGB)
base_url = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/"

# %%
def prepare_image(img_string):
  img = url_to_image(base_url + img_string)
  return img

# %%
img = prepare_image("obj1.jpg")
cv2_imshow(img)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj1.jpg
# <PIL.Image.Image image mode=RGB size=480x269 at 0x7F4FBA9CFDA0>

# %%
def grabCut(image, rect, iterCount=5):
    mask = np.zeros(image.shape[:2], np.uint8)
    
    bgdModel = np.zeros((1, 65), np.float64)
    fgdModel = np.zeros((1, 65), np.float64)
    
    cv2.grabCut(image, mask, rect, bgdModel, fgdModel, iterCount, cv2.GC_INIT_WITH_RECT)
    
    mask2 = np.where((mask == 2) | (mask == 0), 0, 1).astype("uint8")
    
    return image * mask2[:, :, np.newaxis]

# %%
res = grabCut(img, (20, 20, 440, 220), 3)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=RGB size=480x269 at 0x7F4FB9A8B0F0>

# %%
img = prepare_image("obj2.jpg")
cv2_imshow(img)
res = grabCut(img, (40, 40, 440, 250), 10)
cv2_imshow(res)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj2.jpg
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F4FB9A8D550>
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F4FB9A7B978>

# %%
img = prepare_image("obj3.jpg")
cv2_imshow(img)
res = grabCut(img, (40, 40, 240, 200), 5)
cv2_imshow(res)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj3.jpg
# <PIL.Image.Image image mode=RGB size=480x376 at 0x7F4FB9A7F9B0>
# <PIL.Image.Image image mode=RGB size=480x376 at 0x7F4FB9A7F400>

# %%
img = prepare_image("obj4.jpg")
cv2_imshow(img)
res = grabCut(img, (40, 30, 400, 300), 15)
cv2_imshow(res)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj4.jpg
# <PIL.Image.Image image mode=RGB size=480x319 at 0x7F4FB9A948D0>
# <PIL.Image.Image image mode=RGB size=480x319 at 0x7F4FB9A7F748>

# %%
img = prepare_image("obj5.jpg")
cv2_imshow(img)
res = grabCut(img, (40, 10, 400, 300), 15)
cv2_imshow(res)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj5.jpg
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F4FB9A7F4A8>
# <PIL.Image.Image image mode=RGB size=480x320 at 0x7F4FB9A7F5C0>

# %%
img = prepare_image("obj6.jpg")
cv2_imshow(img)
res = grabCut(img, (60, 70, 180, 380), 1)
cv2_imshow(res)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj6.jpg
# <PIL.Image.Image image mode=RGB size=319x480 at 0x7F4FB9A8BE48>
# <PIL.Image.Image image mode=RGB size=319x480 at 0x7F4FB9A8BE80>
